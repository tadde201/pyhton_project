# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\tadde\Desktop\project form.csv')
print(df.describe())
# Out:
#        Daily hospital occupancy
# count              22708.000000
# mean                4064.180333
# std                11614.614806
# min                    0.000000
# 25%                  117.000000
# 50%                  603.000000
# 75%                 2568.250000
# max               154536.000000

# %%
maxh=df['Daily hospital occupancy'].max()
print('maxumum',maxh)
df.describe()
# Out:
# maxumum 154536
#        Daily hospital occupancy
# count              22708.000000
# mean                4064.180333
# std                11614.614806
# min                    0.000000
# 25%                  117.000000
# 50%                  603.000000
# 75%                 2568.250000
# max               154536.000000

# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\tadde\Desktop\project form.csv')
Min=df['Daily hospital occupancy'].min()
print('Minmum of hosibitality',Min)
# Out:
# Minmum of hosibitality 0

# %%
import pandas as pd
import numpy as py
sumof=df['Daily hospital occupancy'].sum()
print('The sum of all dath',sumof)
# Out:
# The sum of all dath 92289407

# %%
import matplotlib.pyplot as plt
df.plot(x='Entity', y='Daily hospital occupancy', kind='line')
plt.title('country by dath')
plt.xlabel('Entity')
plt.ylabel('Daily hospital occupancy')

# Save the chart to a file
plt.savefig('sales_report.png')

# %%
print(df.describe())
# Out:
#        Daily hospital occupancy
# count              22708.000000
# mean                4064.180333
# std                11614.614806
# min                    0.000000
# 25%                  117.000000
# 50%                  603.000000
# 75%                 2568.250000
# max               154536.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22708 entries, 0 to 22707
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Entity                    22708 non-null  object
#  1   Code                      22708 non-null  object
#  2   Day                       22708 non-null  object
#  3   Daily hospital occupancy  22708 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 709.8+ KB

# %%
print(df.describe())
# Out:
#        Daily hospital occupancy
# count              22708.000000
# mean                4064.180333
# std                11614.614806
# min                    0.000000
# 25%                  117.000000
# 50%                  603.000000
# 75%                 2568.250000
# max               154536.000000

# %%
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, 35, 40, 45],
        'Salary': [50000, 60000, 70000, 80000, 90000]}
df = pd.DataFrame(data)

# Get descriptive statistics of the numerical columns
print(df.describe())
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   35.000000  70000.000000
# std     7.905694  15811.388301
# min    25.000000  50000.000000
# 25%    30.000000  60000.000000
# 50%    35.000000  70000.000000
# 75%    40.000000  80000.000000
# max    45.000000  90000.000000

# %%
a=17
b=0.5
profit=a*b
print(profit)
# Out:
# 8.5

# %%
nettotal=profit*0.20
print(nettotal)
# Out:
# 1.7000000000000002

# %%
nettotal=1.7000000000000002
Netfact=round(nettotal,5)
print(Netfact)
# Out:
# 1.7

# %%
'saturday'.upper()
# Out:
# 'SATURDAY'
