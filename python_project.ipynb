# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
df=pd.read_csv(r"C:\Users\tadde\Desktop\BI\electric_vehicle_analytics.csv")

# %%
df.head()
# Out:
#    Vehicle_ID     Make          Model  Year         Region Vehicle_Type  \
# 0           1   Nissan           Leaf  2021           Asia          SUV
# 1           2   Nissan           Leaf  2020      Australia        Sedan
# 2           3  Hyundai  Kona Electric  2021  North America          SUV
# 3           4     Audi      Q4 e-tron  2022         Europe    Hatchback
# 4           5    Tesla        Model 3  2022      Australia        Truck
#
#    Battery_Capacity_kWh  Battery_Health_%  Range_km  Charging_Power_kW  ...  \
# 0                 101.7              75.5       565              153.6  ...
# 1                  30.1              99.8       157              157.2  ...
# 2                 118.5              84.0       677              173.6  ...
# 3                  33.1              97.3       149              169.3  ...
# 4                  81.3              85.6       481              212.8  ...
#
#    Max_Speed_kmh  Acceleration_0_100_kmh_sec  Temperature_C  Usage_Type  \
# ...

# %%
df.tail()
# Out:
#       Vehicle_ID      Make           Model  Year         Region Vehicle_Type  \
# 2995        2996  Mercedes             EQS  2021  North America          SUV
# 2996        2997      Ford  Mustang Mach-E  2022         Europe    Hatchback
# 2997        2998       Kia         Niro EV  2024         Europe        Truck
# 2998        2999  Mercedes             EQC  2015  North America        Truck
# 2999        3000      Audi       Q4 e-tron  2023  North America    Hatchback
#
#       Battery_Capacity_kWh  Battery_Health_%  Range_km  Charging_Power_kW  \
# 2995                  57.2              84.0       239              102.2
# 2996                  98.4              83.1       498              160.6
# 2997                  35.1              82.1       189               18.1
# 2998                  69.4              98.4       336               94.7
# 2999                  70.2              82.6       387              232.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Vehicle_ID                        3000 non-null   int64
#  1   Make                              3000 non-null   object
#  2   Model                             3000 non-null   object
#  3   Year                              3000 non-null   int64
#  4   Region                            3000 non-null   object
#  5   Vehicle_Type                      3000 non-null   object
#  6   Battery_Capacity_kWh              3000 non-null   float64
#  7   Battery_Health_%                  3000 non-null   float64
#  8   Range_km                          3000 non-null   int64
#  9   Charging_Power_kW                 3000 non-null   float64
#  10  Charging_Time_hr                  3000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Vehicle_ID         Year  Battery_Capacity_kWh  Battery_Health_%  \
# count  3000.000000  3000.000000           3000.000000       3000.000000
# mean   1500.500000  2019.499667             74.810100         85.030000
# std     866.169729     2.848047             25.734079          8.589526
# min       1.000000  2015.000000             30.000000         70.000000
# 25%     750.750000  2017.000000             53.000000         77.775000
# 50%    1500.500000  2020.000000             74.850000         85.250000
# 75%    2250.250000  2022.000000             96.900000         92.300000
# max    3000.000000  2024.000000            120.000000        100.000000
#
#           Range_km  Charging_Power_kW  Charging_Time_hr  Charge_Cycles  \
# count  3000.000000        3000.000000       3000.000000    3000.000000
# mean    374.414667         129.301000          1.203570    1107.009667
# std     137.184112          68.742745          1.421866     510.834590
# ...

# %%
Group=df.groupby('Make').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
Group
# Out:
#          Make  counts
# 3        Ford     323
# 1         BMW     311
# 2   Chevrolet     308
# 9  Volkswagen     308
# 7      Nissan     298
# 4     Hyundai     297
# 6    Mercedes     293
# 0        Audi     289
# 8       Tesla     287
# 5         Kia     286

# %%
# Add values on top of bars


plt.figure(figsize=(12,6))
ax = sns.barplot(data=Group.head(10), x='Make', y='counts')  

# Add values on top of bars (after ax is created)
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),   # show as integer
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),  # vertical offset
        textcoords='offset points'
    )

plt.title('Top 10 Electric Vehicle Makes')
plt.xlabel('Make')
plt.ylabel('Number of Vehicles')
plt.show()

# %%
df
# Out:
#       Vehicle_ID      Make           Model  Year         Region Vehicle_Type  \
# 0              1    Nissan            Leaf  2021           Asia          SUV
# 1              2    Nissan            Leaf  2020      Australia        Sedan
# 2              3   Hyundai   Kona Electric  2021  North America          SUV
# 3              4      Audi          Taycan  2022         Europe    Hatchback
# 4              5     Tesla         Model 3  2022      Australia        Truck
# ...          ...       ...             ...   ...            ...          ...
# 2995        2996  Mercedes             EQS  2021  North America          SUV
# 2996        2997      Ford  Mustang Mach-E  2022         Europe    Hatchback
# 2997        2998       Kia         Niro EV  2024         Europe        Truck
# 2998        2999  Mercedes             EQC  2015  North America        Truck
# 2999        3000      Audi       Q4 e-tron  2023  North America    Hatchback
#
# ...

# %%
BatteryHealth = (
    df.groupby('Make')['Battery_Capacity_kWh']
      .sum()
      .reset_index(name='Battery_Capacity_kWh')
      .sort_values(by='Battery_Capacity_kWh', ascending=True)
)
BatteryHealth
# Out:
#          Make  Battery_Capacity_kWh
# 5         Kia               20783.2
# 8       Tesla               21208.1
# 0        Audi               21818.0
# 7      Nissan               21879.0
# 6    Mercedes               22197.2
# 9  Volkswagen               22199.3
# 4     Hyundai               22596.0
# 2   Chevrolet               23063.2
# 1         BMW               24132.6
# 3        Ford               24553.7

# %%
BatteryHealth = (
    df.groupby(['Region','Make'])['Battery_Capacity_kWh']
      .sum()
      .reset_index(name='Battery_Capacity_kWh')
      .sort_values(by='Region', ascending=True)
)
BatteryHealth
# Out:
#            Region        Make  Battery_Capacity_kWh
# 0            Asia        Audi                5321.8
# 1            Asia         BMW                6032.4
# 2            Asia   Chevrolet                5648.7
# 3            Asia        Ford                6622.8
# 4            Asia     Hyundai                6761.8
# 5            Asia         Kia                4999.3
# 6            Asia    Mercedes                4771.3
# 7            Asia      Nissan                5888.2
# 8            Asia       Tesla                4690.2
# 9            Asia  Volkswagen                4633.4
# 18      Australia       Tesla                5407.4
# 17      Australia      Nissan                6120.1
# 16      Australia    Mercedes                5757.1
# 15      Australia         Kia                5074.5
# 19      Australia  Volkswagen                5975.7
# 13      Australia        Ford                6863.3
# 12      Australia   Chevrolet                5737.5
# ...

# %%
BatteryHealth.to_csv('BatteryHealth.csv', index=False)

# %%
BatteryHealth = (
    df.groupby(['Region','Make'])['Battery_Capacity_kWh']
      .sum()
      .reset_index(name='Battery_Capacity_kWh')
      .sort_values(by='Region', ascending=True)
)
BatteryHealth
# Out:
#            Region        Make  Battery_Capacity_kWh
# 0            Asia        Audi                5321.8
# 1            Asia         BMW                6032.4
# 2            Asia   Chevrolet                5648.7
# 3            Asia        Ford                6622.8
# 4            Asia     Hyundai                6761.8
# 5            Asia         Kia                4999.3
# 6            Asia    Mercedes                4771.3
# 7            Asia      Nissan                5888.2
# 8            Asia       Tesla                4690.2
# 9            Asia  Volkswagen                4633.4
# 18      Australia       Tesla                5407.4
# 17      Australia      Nissan                6120.1
# 16      Australia    Mercedes                5757.1
# 15      Australia         Kia                5074.5
# 19      Australia  Volkswagen                5975.7
# 13      Australia        Ford                6863.3
# 12      Australia   Chevrolet                5737.5
# ...

# %%
BatteryHealth = (
    df.groupby('Region')['Battery_Capacity_kWh']
      .sum()
      .reset_index(name='Battery_Capacity_kWh')
      .sort_values(by='Region', ascending=True)
)

BatteryHealth
# Out:
#           Region  Battery_Capacity_kWh
# 0           Asia               55369.9
# 1      Australia               58143.7
# 2         Europe               54399.3
# 3  North America               56517.4

# %%
# Sort data first by battery capacity
BatteryHealth_sorted = BatteryHealth.sort_values(by='Battery_Capacity_kWh', ascending=False)

plt.figure(figsize=(12,6))
ax = sns.barplot(data=BatteryHealth_sorted, x='Region', y='Battery_Capacity_kWh')

# Add values on top of bars
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),
        textcoords='offset points'
    )
plt.title('Total Battery Capacity by Region')
plt.xlabel('Region'
plt.ylabel('Total Battery Capacity (kWh)')
plt.show()

# %%
df
# Out:
#       Vehicle_ID      Make           Model  Year         Region Vehicle_Type  \
# 0              1    Nissan            Leaf  2021           Asia          SUV
# 1              2    Nissan            Leaf  2020      Australia        Sedan
# 2              3   Hyundai   Kona Electric  2021  North America          SUV
# 3              4      Audi          Taycan  2022         Europe    Hatchback
# 4              5     Tesla         Model 3  2022      Australia        Truck
# ...          ...       ...             ...   ...            ...          ...
# 2995        2996  Mercedes             EQS  2021  North America          SUV
# 2996        2997      Ford  Mustang Mach-E  2022         Europe    Hatchback
# 2997        2998       Kia         Niro EV  2024         Europe        Truck
# 2998        2999  Mercedes             EQC  2015  North America        Truck
# 2999        3000      Audi       Q4 e-tron  2023  North America    Hatchback
#
# ...

# %%
Makes= df.groupby(['Region','Make']).size().reset_index(name='counts').sort_values(by='Make', ascending=True)
Makes
# Out:
#            Region        Make  counts
# 0            Asia        Audi      71
# 30  North America        Audi      61
# 10      Australia        Audi      86
# 20         Europe        Audi      71
# 21         Europe         BMW      88
# 1            Asia         BMW      81
# 31  North America         BMW      69
# 11      Australia         BMW      73
# 2            Asia   Chevrolet      82
# 12      Australia   Chevrolet      77
# 22         Europe   Chevrolet      81
# 32  North America   Chevrolet      68
# 33  North America        Ford      73
# 13      Australia        Ford      91
# 23         Europe        Ford      71
# 3            Asia        Ford      88
# 4            Asia     Hyundai      84
# 14      Australia     Hyundai      75
# 24         Europe     Hyundai      67
# 34  North America     Hyundai      71
# 25         Europe         Kia      65
# 35  North America         Kia      84
# 15      Australia         Kia      72
# 5            Asia         Kia      65
# ...

# %%
plt.figure(figsize=(16,8))

ax = sns.barplot(
    data=Makes,
    x='Region',
    y='counts',
    hue='Make' , # creates clustered/grouped bars
    dodge=True       # separates bars for each hue
)
# Move the legend to the right
ax.legend(title='Make', loc='upper right', bbox_to_anchor=(1, 0.5))
# Add values on top of bars
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='center',
        xytext=(0, 8),
        textcoords='offset points'
    )

plt.title('Number of Makes by Region')
plt.xlabel('Region')
plt.ylabel('Counts')
plt.show()

# %%
# Interactive plot to select Make and see counts by Region
def plot_make(selected_make):
    data = Makes[Makes['Make'] == selected_make]
    plt.figure(figsize=(16,8))
    ax = sns.barplot(data=data, x='Region', y='counts', hue='Make', dodge=True)
    ax.legend(title='Region', loc='center left', bbox_to_anchor=(1, 0.5))
    
    for p in ax.patches:
        ax.annotate(
            format(p.get_height(), '.0f'),
            (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center',
            xytext=(0, 8),
            textcoords='offset points'
        )
    
    plt.title(f'Number of Vehicles for {selected_make} by Region')
    plt.xlabel('Region')
    plt.ylabel('Counts')
    plt.show()

interact(plot_make, selected_make=sorted(Makes['Make'].unique()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 22
#      19     plt.ylabel('Counts')
#      20     plt.show()
# ---> 22 interact(plot_make, selected_make=sorted(Makes['Make'].unique()))
#
# NameError: name 'interact' is not defined
