# %%
import pandas as pd
import numpy as py

# %%
#first project

# %%
data=pd.read_csv(r"C:\Users\tadde\Desktop\Pyhtondemo\PythonRepo/wellness_sales_dataset.csv")

# %%
data.describe()
# Out:
#        Unit Price    Quantity  Total Revenue
# count  200.000000  200.000000     200.000000
# mean   156.818750    3.035000     469.903750
# std     87.033982    1.397692     365.848528
# min     11.000000    1.000000      22.880000
# 25%     82.490000    2.000000     180.910000
# 50%    151.510000    3.000000     321.820000
# 75%    233.417500    4.000000     724.680000
# max    299.240000    5.000000    1496.200000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          200 non-null    object
#  1   Product Name      200 non-null    object
#  2   Category          200 non-null    object
#  3   Sales Channel     200 non-null    object
#  4   Date              200 non-null    object
#  5   Unit Price        200 non-null    float64
#  6   Quantity          200 non-null    int64
#  7   Customer Segment  200 non-null    object
#  8   Region            200 non-null    object
#  9   Total Revenue     200 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 15.8+ KB

# %% [markdown]
# data.head()

# %%
data.head()
# Out:
#                                Order ID  Product Name           Category  \
# 0  0ef3eddb-16c4-4ae0-a586-e209fbd1d661     World Fit  Fitness Equipment
# 1  b67175ea-2817-4e87-85cb-66e70c880c14  Clearly Plus  Fitness Equipment
# 2  82e77c14-6476-405f-9c58-91fb6da22f56    State Plus   Natural Products
# 3  953763e0-1d6d-49a0-9262-1b7ccc59af31   Pretty Plus   Natural Products
# 4  32887666-eae6-4f0e-abae-75ee0b631a3e    Scene Plus  Fitness Equipment
#
#   Sales Channel        Date  Unit Price  Quantity Customer Segment    Region  \
# 0  Retail Store  2025-03-28      198.84         5              Gym   Germany
# 1    E-commerce  2025-06-19      154.04         2              Gym   Germany
# 2      WhatsApp  2025-03-22      134.07         2       Individual     Spain
# 3    E-commerce  2025-07-04      191.42         5              Gym  Portugal
# 4  Retail Store  2025-02-10      257.66         5       Individual   Germany
#
#    Total Revenue
# 0         994.20
# 1         308.08
# ...

# %%
Gr=data['Region'].describe()
print(Gr)
# Out:
# count       200
# unique        5
# top       Spain
# freq         47
# Name: Region, dtype: object

# %%
data.tail()
# Out:
#                                  Order ID Product Name           Category  \
# 195  d415c882-7aa3-4ec3-8237-e6ed60289834  General Fit  Fitness Equipment
# 196  b729485f-226f-4ede-8173-31cc46bd4df8     Lay Plus         Sportswear
# 197  89ebe4dc-cdd5-413a-ad1c-6f8aa1ee7d23    Score Zen         Sportswear
# 198  b419560f-5214-4512-a6b2-02fec9dcff98  Relate Plus        Supplements
# 199  41123eef-25ab-4c08-88f0-6a445374aad2     Item Fit   Natural Products
#
#     Sales Channel        Date  Unit Price  Quantity     Customer Segment  \
# 195    E-commerce  2025-01-15      110.84         5  Health Professional
# 196      WhatsApp  2025-07-05      284.30         3           Individual
# 197      WhatsApp  2025-01-15      248.78         5                  Gym
# 198    E-commerce  2025-04-27      120.33         1           Individual
# 199      WhatsApp  2025-05-15       81.21         4  Health Professional
#
#        Region  Total Revenue
# 195   Germany         554.20
# ...

# %%
data["Unit Price"].max()
data["Unit Price"].min()
# Out:
# 11.0

# %%
print(data.columns.tolist())
# Out:
# ['Order ID', 'Product Name', 'Category', 'Sales Channel', 'Date', 'Unit Price', 'Quantity', 'Customer Segment', 'Region', 'Total Revenue']

# %%
df=data[[ 'Product Name', 'Category', 'Sales Channel', 'Date', 'Unit Price', 'Quantity', 'Customer Segment', 'Region', 'Total Revenue']]
df.head()
# Out:
#    Product Name           Category Sales Channel        Date  Unit Price  \
# 0     World Fit  Fitness Equipment  Retail Store  2025-03-28      198.84
# 1  Clearly Plus  Fitness Equipment    E-commerce  2025-06-19      154.04
# 2    State Plus   Natural Products      WhatsApp  2025-03-22      134.07
# 3   Pretty Plus   Natural Products    E-commerce  2025-07-04      191.42
# 4    Scene Plus  Fitness Equipment  Retail Store  2025-02-10      257.66
#
#    Quantity Customer Segment    Region  Total Revenue
# 0         5              Gym   Germany         994.20
# 1         2              Gym   Germany         308.08
# 2         2       Individual     Spain         268.14
# 3         5              Gym  Portugal         957.10
# 4         5       Individual   Germany        1288.30

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\tadde\AppData\Local\Temp\ipykernel_348\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.groupby('Region').sum().sort_values('Unit Price', ascending=False)
# Out:
# C:\Users\tadde\AppData\Local\Temp\ipykernel_348\2805936034.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum().sort_values('Unit Price', ascending=False)
#           Unit Price  Quantity  Total Revenue
# Region
# Spain        6917.75       135       18014.28
# Portugal     6629.11       124       22655.22
# Brazil       6330.18        99       17197.93
# France       6122.64       127       17934.03
# Germany      5364.07       122       18179.29

# %%
df.groupby("Region")["Total Revenue"].sum().sort_values(ascending=False).head(1)
# Out:
# Region
# Portugal    22655.22
# Name: Total Revenue, dtype: float64

# %%
#min revenue 

df.groupby("Region")["Total Revenue"].sum().sort_values(ascending=False).tail(1)
print(df.columns.tolist())
# Out:
# ['Product Name', 'Category', 'Sales Channel', 'Date', 'Unit Price', 'Quantity', 'Customer Segment', 'Region', 'Total Revenue']

# %%
df
# Out:
#      Product Name           Category Sales Channel        Date  Unit Price  \
# 0       World Fit  Fitness Equipment  Retail Store  2025-03-28      198.84
# 1    Clearly Plus  Fitness Equipment    E-commerce  2025-06-19      154.04
# 2      State Plus   Natural Products      WhatsApp  2025-03-22      134.07
# 3     Pretty Plus   Natural Products    E-commerce  2025-07-04      191.42
# 4      Scene Plus  Fitness Equipment  Retail Store  2025-02-10      257.66
# ..            ...                ...           ...         ...         ...
# 195   General Fit  Fitness Equipment    E-commerce  2025-01-15      110.84
# 196      Lay Plus         Sportswear      WhatsApp  2025-07-05      284.30
# 197     Score Zen         Sportswear      WhatsApp  2025-01-15      248.78
# 198   Relate Plus        Supplements    E-commerce  2025-04-27      120.33
# 199      Item Fit   Natural Products      WhatsApp  2025-05-15       81.21
#
#      Quantity     Customer Segment    Region  Total Revenue
# ...

# %%
df.groupby('Region').max().sort_values('Quantity', ascending=False)
# Out:
#           Product Name     Category Sales Channel        Date  Unit Price  \
# Region
# Brazil    Yourself Fit  Supplements      WhatsApp  2025-07-02      286.04
# France        Well Fit  Supplements      WhatsApp  2025-06-24      297.80
# Germany      World Fit  Supplements      WhatsApp  2025-07-05      297.28
# Portugal      Yes Plus  Supplements      WhatsApp  2025-07-04      299.24
# Spain         Type Zen  Supplements      WhatsApp  2025-07-04      294.60
#
#           Quantity Customer Segment  Total Revenue
# Region
# Brazil           5       Individual        1336.55
# France           5       Individual        1462.30
# Germany          5       Individual        1288.30
# Portugal         5       Individual        1496.20
# Spain            5       Individual        1116.85

# %%
df.groupby('Region').min().sort_values('Quantity', ascending=False)
# Out:
#          Product Name           Category Sales Channel        Date  \
# Region
# Brazil    Ability Zen  Fitness Equipment    E-commerce  2025-01-06
# France        Box Max  Fitness Equipment    E-commerce  2025-01-11
# Germany     Also Plus  Fitness Equipment    E-commerce  2025-01-08
# Portugal   Amount Max  Fitness Equipment    E-commerce  2025-01-07
# Spain      Avoid Plus  Fitness Equipment    E-commerce  2025-01-06
#
#           Unit Price  Quantity Customer Segment  Total Revenue
# Region
# Brazil         11.00         1              Gym          33.00
# France         11.44         1              Gym          22.88
# Germany        15.31         1              Gym          44.60
# Portugal       26.90         1              Gym          26.90
# Spain          12.06         1              Gym          36.18

# %%
print(df.columns.to_list())
df.groupby('Region')['Sales Channel'].value_counts().reset_index(name='WhatsApp').sort_values('WhatsApp', ascending=False)
Whatsapps= df.groupby('Region')['Sales Channel'].value_counts().reset_index(name='WhatsApp').sort_values('WhatsApp', ascending=False)
Whatsapps
# Out:
# ['Product Name', 'Category', 'Sales Channel', 'Date', 'Unit Price', 'Quantity', 'Customer Segment', 'Region', 'Total Revenue']
#       Region Sales Channel  WhatsApp
# 16     Spain      WhatsApp        17
# 12  Portugal      WhatsApp        15
# 17     Spain  Retail Store        14
# 4     France      WhatsApp        14
# 0     Brazil  Retail Store        12
# 18     Spain    E-commerce        12
# 8    Germany    E-commerce        12
# 5     France    E-commerce        11
# 1     Brazil    E-commerce        11
# 6     France  Retail Store        10
# 13  Portugal    E-commerce         9
# 14  Portugal  Retail Store         8
# 10   Germany      WhatsApp         8
# 9    Germany     Instagram         8
# 7     France     Instagram         8
# 2     Brazil      WhatsApp         8
# 15  Portugal     Instagram         7
# 11   Germany  Retail Store         6
# 3     Brazil     Instagram         6
# 19     Spain     Instagram         4

# %%
df.groupby('Region')['Sales Channel'].value_counts().reset_index(name='WhatsApp').sort_values('WhatsApp', ascending=False)
# Out:
#       Region Sales Channel  WhatsApp
# 16     Spain      WhatsApp        17
# 12  Portugal      WhatsApp        15
# 17     Spain  Retail Store        14
# 4     France      WhatsApp        14
# 0     Brazil  Retail Store        12
# 18     Spain    E-commerce        12
# 8    Germany    E-commerce        12
# 5     France    E-commerce        11
# 1     Brazil    E-commerce        11
# 6     France  Retail Store        10
# 13  Portugal    E-commerce         9
# 14  Portugal  Retail Store         8
# 10   Germany      WhatsApp         8
# 9    Germany     Instagram         8
# 7     France     Instagram         8
# 2     Brazil      WhatsApp         8
# 15  Portugal     Instagram         7
# 11   Germany  Retail Store         6
# 3     Brazil     Instagram         6
# 19     Spain     Instagram         4

# %%
Whatsapps
Whatsapps.to_csv('Whatsapps.csv', index=False)
Whatsapps
# Out:
#       Region Sales Channel  WhatsApp
# 16     Spain      WhatsApp        17
# 12  Portugal      WhatsApp        15
# 17     Spain  Retail Store        14
# 4     France      WhatsApp        14
# 0     Brazil  Retail Store        12
# 18     Spain    E-commerce        12
# 8    Germany    E-commerce        12
# 5     France    E-commerce        11
# 1     Brazil    E-commerce        11
# 6     France  Retail Store        10
# 13  Portugal    E-commerce         9
# 14  Portugal  Retail Store         8
# 10   Germany      WhatsApp         8
# 9    Germany     Instagram         8
# 7     France     Instagram         8
# 2     Brazil      WhatsApp         8
# 15  Portugal     Instagram         7
# 11   Germany  Retail Store         6
# 3     Brazil     Instagram         6
# 19     Spain     Instagram         4

# %%
Whatsapps


Whatsapps.to_excel('Whatsapps.xlsx', index=False, header=True)
