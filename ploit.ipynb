# %%
from matplotlib import pyplot as plt

# %%
x=[12,40,60,80]
y=[15,60,70,100]

# %%
plt.plot(x,y)

# %%
plt.plot(y,x)

# %%
import seaborn as sns

# %%
import matplotlip as lip

# %%
sns.set()

# %%
plt.plot(x,y)
