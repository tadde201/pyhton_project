# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd()))
from job_fit_analysis import analyze_job_fit

# %%
my_skills = """
SQL, Power BI, Python, ETL, Azure Data Factory, SSIS,
Data Warehouse, Databricks, Snowflake, Pandas, Excel,
Data Modeling, Reporting, Dashboard Development
"""

job_description = """
We are seeking a Data Analyst with strong SQL skills,
Power BI experience, and Python knowledge. Candidate should
understand ETL pipelines and data modeling. Azure experience
is a plus.
"""

# %%
my_skills = """
SQL Server, Power BI, Python, SSIS, Azure Data Factory, Excel, Data Analysis
"""

job_desc = """
We are looking for a Data Engineer with experience in SQL, Azure Data Factory, Databricks, PySpark, and data pipelines.
"""

analysis = analyze_job_fit(my_skills, job_desc)

# %%
print(analysis)
# Out:
# Fit Score: 42%
# Decision: NOT FIT
# Matching Skills: azure, data, data factory, factory, sql
# Missing Skills: data engineer, data pipelines, databricks, engineer, experience, pipelines, pyspark
# Skill Gap Advice: Focus on improving the following gaps: data engineer, data pipelines, databricks, engineer, experience.
