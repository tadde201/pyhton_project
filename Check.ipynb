# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd()))
from job_fit_analysis import analyze_job_fit

# %%
my_skills = """
QL, Power BI, Python, ETL, Azure Data Factory, SSIS,
Data Warehouse, Databricks, Snowflake, Pandas, Excel,Data Engineering & ETL: ETL, Data Pipeline, Data Mapping, Data Processing, Data Warehousing, SSIS, Azure Data Factory, ETL/ELT process, Data Migration
Technical Development: SQL, T-SQL, Python, PySpark, Spark SQL, Databricks, DDL/DML/DCL, Stored Procedures, Performance Tuning
Analytics & Visualization: Data Analytics, Power BI, DAX, SSRS, Power Query, Data Modeling, Visualization
Methodologies & Operations: Troubleshooting, Data Validation, Root Cause Analysis, Agile, Jira, Data Security, Docker
Using daily task AI like CHATGPT, Claude , Copilot  and other AI tools
 analysis, data, development, methodologies, security, ssis, technical, using
 acceptance, administration, among, architecture, area, assist, builds, business, capability, cloud, complex, conclusion, connectivity, controls, creates, creating, database, databases, dbe, design, developing, develops, distribution, document, domain, efforts, end, evaluation, existing, expertise, file, fits, flow, from, front, has, hoc, implementation, improvements, inception, information, initial, into, ioc, its, lifecyclerequirements, loading, logical, long, macros, maintenance, make, manipulate, master, matter, new, number, object, ones, open, operational, optimization, oriented, overall, parser, particular, physical, primarily, project, projects, provides, queries, range, recommendations, recreating, relational, requirements, response, responsible, retention, retrieval, rules, scripts, set, simple, software, storage, structure, subject, system, systems, tables, technology, testing, that, through, times, trades, translates, under, updates, usable, users, volumes, works
Skill Gap Advice: Focus on improving the following gaps: acceptance, administration, among, architecture, area.
"""

job_desc = """
Provides technical expertise for database design, development,
implementation, information storage and retrieval, data flow and
analysis. Develops relational and/or Object-Oriented databases,
database parser software, and database loading software. Projects
long-range requirements for database administration and design.
Responsible for developing a database structure that fits into the
overall architecture of the system under development and has to make
trades among data volumes, number of users, logical and physical
distribution, response times, retention rules, security and domain
controls. The DBE works primarily at the front end of the lifecyclerequirements
through system acceptance testing and Initial Operational
Capability (IOC). Develops requirements from a project’s inception to
its conclusion for a particular business and Information Technology
(IT) subject matter area (i.e., simple to complex systems). Assist with
recommendations for, and analysis and evaluation of systems
improvements, optimization, development, and/or maintenance efforts.
Translates a set of requirements and data into a usable document by
creating or recreating ad hoc queries, scripts, and macros; updates
existing queries, creates new ones to manipulate data into a master
file; and builds complex systems using queries, tables, Open Database
Connectivity and database storage and retrieval using Cloud
methodologies...
"""
analysis = analyze_job_fit(my_skills, job_desc)

# %%
print(analysis)
# Out:
# Fit Score: 100%
# Decision: FIT
# ...
