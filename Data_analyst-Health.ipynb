# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\tadde\Desktop\BI\StressLevelDataset.csv")

# %%
df
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
df.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# 1097               2              5                  2            2
# 1098               3              1                  4            3
# 1099               3              0                  3            3
#
#       living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.shape
# Out:
# (1100, 22)

# %%
df.head()
df.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# 1097               2              5                  2            2
# 1098               3              1                  4            3
# 1099               3              0                  3            3
#
#       living_conditions  ...  academic_performance  study_load  \
# ...

# %%
# Define bins and labels
bins = [0, 10, 20, float('inf')]   # Low: 0-10, Medium: 11-20, High: 21+
labels = ['Low', 'Medium', 'High']

# %%
# Create new column
df['self_esteemstatus'] = pd.cut(df['self_esteem'], bins=bins, labels=labels, right=True)
# Check results
print(df[['self_esteem', 'self_esteemstatus']].head())
df
# Out:
#    self_esteem self_esteemstatus
# 0           20            Medium
# 1            8               Low
# 2           18            Medium
# 3           12            Medium
# 4           28              High
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# ...

# %%
plt.figure(figsize=(10,6))
order = df['self_esteemstatus'].value_counts().index
ax = sns.countplot(data=df, x='self_esteemstatus',order=order)  # only x, no y

# Add values on top of bars
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),   # show as integer
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),  # vertical offset
        textcoords='offset points'
    )

plt.title('Stress Level Distribution')
plt.xlabel('self_esteemstatus')
plt.ylabel('Count')
plt.show()

# %%
df
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
bins = [0, 9, 15, 50]  # ranges: 0-10 = Low, 11-20 = Medium, 21+ = High
labels = ['Low', 'Medium', 'High']

# %%
df['status'] = pd.cut(df['depression'], bins=bins, labels=labels, right=True)

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  academic_performance  study_load  \
# ...

# %%
df[['self_esteem','depression','status']]
# Out:
#       self_esteem  depression  status
# 0              20          11  Medium
# 1               8          15  Medium
# 2              18          14  Medium
# 3              12          15  Medium
# 4              28           7     Low
# ...           ...         ...     ...
# 1095           17          14  Medium
# 1096           12           8     Low
# 1097           26           3     Low
# 1098            0          19    High
# 1099            6          15  Medium
#
# [1100 rows x 3 columns]

# %%
status_counts = df['status'].value_counts()
print(status_counts)
# Out:
# status
# Low       370
# High      370
# Medium    316
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
# Add values on top of bars
# Create the seaborn countplot and save it to ax
ax = sns.countplot(data=df, x='status', order=['Low','Medium','High'])

# Add values on top of bars
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),   # show as integer
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),  # vertical offset
        textcoords='offset points'
    )

plt.title('Depression Level Distribution')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %%
df
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
plt.figure(figsize=(10,6))
# Add values on top of bars
# Create the seaborn countplot and save it to ax
ax = sns.countplot(data=df, x='status', order=['Low','Medium','High'])

# Add values on top of bars
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),   # show as integer
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),  # vertical offset
        textcoords='offset points'
    )


counts = df['status'].value_counts()
fig, ax = plt.subplots(figsize=(6,4))
bars = ax.bar(counts.index, counts.values)
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# %%
avg_depression = df.groupby('mental_health_history')['status'].count()
print(avg_depression)
# Out:
# mental_health_history
# 0    516
# 1    540
# Name: status, dtype: int64

# %%
plt.figure(figsize=(10,6))


ax = sns.countplot(data=df, x='status', order=['Low','Medium','High'])

# Add values on top of bars
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f'),   # show as integer
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='center',
        xytext=(0, 8),  # vertical offset
        textcoords='offset points'
    )

plt.title('mental_health_history')
plt.xlabel('mental_health_history')
plt.ylabel('Count')
plt.show()

# %%
avagdepression = df.groupby('mental_health_history')['status'].value_counts().unstack()
avagdepression.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Depression Levels by Mental Health History')
plt.xlabel('mental_health_history')
plt.ylabel('Count')
plt.legend(title='Depression Level')
plt.show()

# %%
avagdepression = df.groupby('mental_health_history')['status'].value_counts().unstack()
avagdepression
# Out:
# status                 Low  Medium  High
# mental_health_history
# 0                      324     147    45
# 1                       46     169   325

# %%
df
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
Nedataset=df
Nedataset
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
Newdata=Nedataset.rename(columns={'self_esteemstatus':'Selfesteem_Status','status':'Depression_Status'})
Newdata
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0                14           20                      0          11         2
# 1                15            8                      1          15         5
# 2                12           18                      1          14         2
# 3                16           12                      1          15         4
# 4                16           28                      0           7         2
# ...             ...          ...                    ...         ...       ...
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
# ...

# %%
Newdata.to_csv('StudentHealth.csv', index=False)
